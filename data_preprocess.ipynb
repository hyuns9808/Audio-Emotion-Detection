# %% [markdown]
# ## Note that 'librosa' ONLY runs on Python 3.9.x, and thus more recent versions of Python kernels would not work.

# %%
# !python3.9 -m venv myenv
# !source myenv/bin/activate
# !pip install --upgrade pip
# !pip install notebook ipykernel
# !python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
# Out:
# /bin/bash: line 1: python3.9: command not found
# /bin/bash: line 1: myenv/bin/activate: No such file or directory
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.0)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.3 MB/s eta 0:00:00 0:00:01
# Installing collected packages: pip
#   WARNING: The scripts pip, pip3 and pip3.10 are installed in '/home/hice1/hyang491/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-24.3.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (6.4.10)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (6.25.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (6.3.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook) (25.1.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (5.9.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (5.3.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook) (8.3.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook) (7.8.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook) (0.17.1)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (8.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.19.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (2.16.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook) (3.10.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook) (4.19.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.10.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.21)
# Installed kernelspec myenv in /home/hice1/hyang491/.local/share/jupyter/kernels/myenv

# %%
import os
import re
import librosa
import noisereduce as nr
import numpy as np
import sys
from scipy.io import wavfile
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.utils import Bunch

# %%
# get location of audio files
root_directory = os.getcwd()

# %%
audio_directory = os.path.join(root_directory, 'ravdess')
nr_directory = os.path.join(root_directory, 'ravdess_NR')
if os.path.exists(nr_directory):
    print("'ravdess_NR' folder already exists, will not run noise reduction; to run it, please delete the file and try again.")
else:
    # Will raise error if folder exists; repetitive, but included as fail-safe
    os.makedirs(nr_directory, exist_ok=False)
    for root, _, files in os.walk(audio_directory):
        relative_path = os.path.relpath(root, audio_directory)
        save_directory = os.path.join(nr_directory, relative_path)
        os.makedirs(save_directory, exist_ok=True)
        print(f"Created directory: {save_directory}")
        
        for file_name in files:
            file_path = os.path.join(root, file_name)
            if file_name.endswith('.wav'):
                rate, data = wavfile.read(file_path)
                # 1) data is mono-channel
                if data.ndim == 1:
                    reduced_noise = nr.reduce_noise(y=data, sr=rate)
                # 2) data is multi-channel
                else:
                    reduced_noise = []
                    for i in range(data.shape[1]):
                        reduced_channel = nr.reduce_noise(y=data[:, i], sr=rate)
                        reduced_noise.append(reduced_channel)
                    reduced_noise = np.stack(reduced_noise, axis=1)
                reduced_noise = reduced_noise.astype(data.dtype)
                reduce_name = f'{os.path.splitext(file_name)[0]}_NR.wav'
                wavfile.write(os.path.join(save_directory, reduce_name), rate, reduced_noise)
        print(f"Completed noise reduction for files in folder {root}")
# Out:
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/.
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_21
# /scratch/1001702/ipykernel_497290/1751505744.py:17: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wavfile.read(file_path)
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_21
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_16
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_16
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_07
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_07
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_14
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_14
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_23
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_23
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_13
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_13
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_24
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_24
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_10
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_10
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_05
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_05
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_12
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_12
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_06
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_06
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_02
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_02
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_03
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_03
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_09
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_09
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_15
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_15
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_19
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_19
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_04
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_04
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_18
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_18
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_01
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_01
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_20
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_20
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_17
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_17
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_22
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_22
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_08
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_08
# Created directory: /storage/ice1/7/4/hyang491/PCA_Audio/ravdess_NR/Actor_11
# Completed noise reduction for files in folder /storage/ice1/7/4/hyang491/PCA_Audio/ravdess/Actor_11

# %%
# !{sys.executable} -m pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/hice1/hyang491/.local/lib/python3.10/site-packages (from librosa) (1.24.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4.2)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.57.1+1.g5fba9aa8f)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (23.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa) (0.40.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
def pad_signal(signal, target_length=512):
    if len(signal) < target_length:
        padding = target_length - len(signal)
        signal = np.pad(signal, (0, padding), 'constant')
    return signal

# %%
def extract_features(file_path, sample_rate=48000, n_fft=512):
    signal, sr = librosa.load(file_path, sr=sample_rate)
    signal = librosa.effects.trim(signal)[0]
    signal = pad_signal(signal, target_length=n_fft)

    mfccs = np.mean(librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=n_fft).T, axis=0)
    chroma_stft = np.mean(librosa.feature.chroma_stft(y=signal, sr=sr, n_fft=n_fft), axis=1)
    mel_spectrogram = np.mean(librosa.feature.melspectrogram(y=signal, sr=sr, n_mels=40, n_fft=n_fft), axis=1)
    spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=signal, sr=sr, n_fft=n_fft))
    spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=signal, sr=sr, n_fft=n_fft))
    spectral_contrast = np.mean(librosa.feature.spectral_contrast(y=signal, sr=sr, n_fft=n_fft), axis=1)
    spectral_rolloff = np.mean(librosa.feature.spectral_rolloff(y=signal, sr=sr, n_fft=n_fft))

    tonnetz = np.mean(librosa.feature.tonnetz(y=signal, sr=sr), axis=1)
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=signal))
    chroma_cqt = np.mean(librosa.feature.chroma_cqt(y=signal, sr=sr), axis=1)
    chroma_cens = np.mean(librosa.feature.chroma_cens(y=signal, sr=sr), axis=1)
    spectral_flatness = np.mean(librosa.feature.spectral_flatness(y=signal))
    rms = np.mean(librosa.feature.rms(y=signal))

    features = np.hstack([
        mfccs, chroma_stft, mel_spectrogram, spectral_centroid, spectral_bandwidth, 
        tonnetz, zcr, chroma_cqt, chroma_cens, spectral_contrast, 
        spectral_flatness, spectral_rolloff, rms
    ])

    return features

# %%
# Function that creates sklearn dataset
# input: audio_directory = path of audio data
# output: original_dataset = dataset of features, labels = labels
def create_dataset(audio_directory):
    file_paths = []
    labels = []

    # pattern to match folder and file names(avoid file errors)
    folderPattern = re.compile(r"Actor_\d{2}")
    filePattern = re.compile(r"\d{2}-\d{2}-\d{2}-\d{2}-\d{2}-\d{2}-\d{2}_NR\.wav")

    for root, _, files in os.walk(audio_directory):
        if folderPattern.match(os.path.basename(root)):
            for file_name in files:
                if filePattern.match(file_name):
                    emotion = int(file_name.split("-")[2])
                    labels.append(emotion)
                    file_paths.append(os.path.join(root, file_name))

    # get features for all files
    all_features = []
    for file in file_paths:
        all_features.append(extract_features(file))

    # convert list of features and labels to np array and create dataset
    all_features = np.array(all_features)
    labels = np.array(labels)

    return all_features, labels

# %%
# Function that runs PCA on sklearn dataset
# input: orig_dataset = original dataset of features, labels = labels, target_variance = default 0.95
# output: pca_features_reduced = reduced dataset of features, labels = labels
def pca_dataset(nr_features, nr_labels, target_variance=0.95):
    # # standardize dataset and apply PCA
    scaler = StandardScaler()
    all_features_scaled = scaler.fit_transform(nr_features)
    pca = PCA(target_variance)
    pca_features_reduced = pca.fit_transform(all_features_scaled)

    print(f"Original number of features: {nr_features.shape[1]}")
    print(f"Reduced number of features with {target_variance * 100}% variance retained: {pca_features_reduced.shape[1]}")

    return pca_features_reduced, nr_labels

# %%
import pickle
# check if there is pickle file for nonreduced dataset; if exists, import data
nonreduced_db_pickle_path = os.path.join(root_directory, 'nonreduced')
print(nonreduced_db_pickle_path)
if os.path.exists(nonreduced_db_pickle_path):
    print("'nonreduced.pkl' file already exists, will load file and not create new dataset; to run it, please delete the file and try again.")
    nonreduced_db_file = open('nonreduced', 'rb')    
    nonreduced_db = pickle.load(nonreduced_db_file)
    nr_features, nr_labels = nonreduced_db
    nonreduced_db_file.close()
# else create dataset and resulting pickle file
else:
    nonreduced_db = create_dataset(nr_directory)
    nr_features, nr_labels = nonreduced_db
    # save dataset as pickle file
    nonreduced_db_file = open('nonreduced', 'ab')
    # source, destination
    pickle.dump(nonreduced_db, nonreduced_db_file)                    
    nonreduced_db_file.close()

# print dataset
print(nr_features)
print(nr_labels)
print(np.shape(nr_features))
print(np.shape(nr_labels))
# Out:
# /storage/ice1/7/4/hyang491/PCA_Audio/nonreduced
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=680
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=832
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=840
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=632
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=740
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=816
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=544
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=856
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=624
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=772
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=864
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=964
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=692
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=648
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=800
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=748
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=596
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=788
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=684
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=804
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=708
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=560
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=820
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=616
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=812
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=760
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=896
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=732
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=780
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=888
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=900
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=848
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=700
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=600
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=672
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=720
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=636
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=668
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=824
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=712
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=656
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=728
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=912
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=628
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=940
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=744
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=792
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=552
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=604
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=872
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=808
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=852
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=676
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=576
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=880
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=752
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=580
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=716
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=572
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=660
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=620
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=724
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=644
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=556
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=652
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=768
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=664
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=612
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=704
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=860
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=688
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=836
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=776
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=756
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=608
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=892
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=844
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=924
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1000
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=504
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=524
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=536
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=640
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=968
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=484
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=564
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=952
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=568
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=456
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=436
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=928
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=464
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=936
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=468
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=520
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=944
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=472
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=476
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=992
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=496
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=984
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=492
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=796
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=432
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=500
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=828
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=588
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=512
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=976
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=488
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=540
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=784
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=920
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=460
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=528
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=592
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=448
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=516
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1016
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=508
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=868
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=904
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=452
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=420
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=960
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=480
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=548
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=736
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=584
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=696
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=876
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=980
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=972
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=884
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1004
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1020
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=916
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=956
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=996
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=948
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=764
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=932
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=908
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=988
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=987
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=532
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=444
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1012
#   return f(*args, **kwargs)
# [[-7.49839539e+02  6.20220375e+01 -1.19297285e+01 ...  3.48926522e-02
#    4.63925439e+03  1.20826857e-02]
#  [-7.24241333e+02  7.22653656e+01 -2.62639294e+01 ...  3.88392955e-02
#    3.98549641e+03  1.33437859e-02]
#  [-8.68214905e+02  4.86408463e+01 -7.70047998e+00 ...  7.03973696e-02
#    6.12351896e+03  3.77656193e-03]
#  ...
#  [-1.03060815e+03  3.42490959e+01 -1.55566275e+00 ...  4.64618415e-01
#    2.51250000e+03  8.05703632e-04]
#  [-7.77870605e+02  6.24671097e+01 -6.52451754e+00 ...  4.18793783e-02
#    4.58490566e+03  6.81798020e-03]
#  [-9.85018250e+02  3.38118591e+01  4.86478861e-03 ...  4.98436421e-01
#    2.49066695e+03  1.40213128e-03]]
# [7 4 2 ... 2 5 1]
# (1440, 108)
# (1440,)

# %%
# check if there is pickle file for reduced dataset; if exists, import data
reduced_db_pickle_path = os.path.join(root_directory, 'reduced')
if os.path.exists(reduced_db_pickle_path):
    print("'reduced.pkl' file already exists, will load file and not create new dataset; to run it, please delete the file and try again.")
    reduced_db_file = open('reduced', 'rb')    
    reduced_db = pickle.load(reduced_db_file)
    r_features, r_labels = reduced_db
    reduced_db_file.close()
# else run PCA on existing dataset and create pickle file
else:
    reduced_db = pca_dataset(nr_features, nr_labels)
    r_features, r_labels = reduced_db
    # save dataset as pickle file
    reduced_db_file = open('reduce', 'ab')
    # source, destination
    pickle.dump(reduced_db, reduced_db_file)                    
    reduced_db_file.close()

# print dataset
print(r_features)
print(r_labels)
print(np.shape(r_features))
print(np.shape(r_labels))
# Out:
# Original number of features: 108
# Reduced number of features with 95.0% variance retained: 37
# [[ 9.59421374e-01 -2.13160858e+00  7.25211966e-01 ... -4.43656085e-01
#    4.28159844e-01 -7.48643626e-01]
#  [ 9.38911866e-01 -1.93406652e+00 -3.22610990e+00 ... -7.69578463e-01
#    7.71518297e-02 -2.28676000e-01]
#  [-6.91222952e-01 -2.48232334e+00 -2.01013177e-01 ... -1.59066861e-01
#    4.83167208e-01 -7.23641057e-01]
#  ...
#  [-6.30042336e+00  4.19348328e+00 -1.45964726e+00 ... -8.47781936e-02
#   -3.91546246e-01 -8.90814901e-02]
#  [-6.57980910e-02 -2.93522051e+00 -2.86158682e+00 ... -1.02629296e-01
#   -2.66436494e-01  5.60885519e-03]
#  [-6.87323239e+00  5.30681823e+00 -1.03469158e+00 ... -1.27583030e-01
#   -2.32364580e-01  3.43872521e-01]]
# [7 4 2 ... 2 5 1]
# (1440, 37)
# (1440,)
